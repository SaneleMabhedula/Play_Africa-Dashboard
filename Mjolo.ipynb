# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # ***HI Gama lam ndingu Sanele Indoda KaMsethwana***
#
# ## Lets talk about uMjolo the pandemic

# %%
df7 = pd.read_csv(r"C:\Users\CDP USER\Documents\relationship_data_analysis.csv" , delimiter = ";")
df7.head(10)

#Create the figure
#Sizoba ifigure yethu

plt.figure(figsize=(10, 6))
sns.heatmap(df7.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Relationship Features")
plt.show()

# %%
sns.boxplot(x='Outcome', y='Communication_Score', data=df7)
plt.title("Communication Score vs Relationship Outcome")
plt.show()

# %%
sns.boxplot(x='Outcome', y='Conflict_Frequency_Per_Month', data=df7)
plt.title("Conflict Frequency vs Relationship Outcome")
plt.show()

# %%
sns.boxplot(x='Outcome', y='Financial_Stress_Level', data=df7)
plt.title("Financial stress vs Relationship Outcome")
plt.show()

# %%
sns.boxplot(x='Outcome', y='Trust_Level', data=df7)
plt.title("Trust Level vs Relationship Outcome")
plt.show()

# %%
df7.groupby("Outcome")["Trust_Level"].mean()
# Out:
# Outcome
# 0    5.347561
# 1    6.416667
# Name: Trust_Level, dtype: float64
